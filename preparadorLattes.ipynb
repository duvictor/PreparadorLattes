# %% [raw]
# Este é um projeto excelente e muito útil para o contexto acadêmico brasileiro. A verificação manual do Lattes é extremamente trabalhosa.
#
# Abaixo, apresento uma solução completa estruturada em formato de Jupyter Notebook. A lógica foi desenhada para ser eficiente: utilizamos o FAISS para encontrar os candidatos mais prováveis (busca semântica) e o GPT-4 apenas para a validação final ("Este certificado realmente comprova este item?"), economizando tokens e aumentando a precisão.
#
# Pré-requisitos
# Certifique-se de ter os arquivos organizados assim:
#
# meu_curriculo.pdf (O arquivo do Lattes)
#
# Uma pasta chamada certificados/ contendo todos os PDFs comprobatórios.
#
# O Código do Notebook
# Copie e cole as células abaixo em seu Jupyter Notebook.
#
# Célula 1: Instalação das Dependências

# %%
# Instalação das bibliotecas necessárias
# !pip install pdfminer.six openai faiss-cpu pandas reportlab numpy
# Out:
# Collecting pdfminer.six
#   Downloading pdfminer_six-20251107-py3-none-any.whl.metadata (4.2 kB)
# Collecting openai
#   Downloading openai-2.8.1-py3-none-any.whl.metadata (29 kB)
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.13.0-cp310-cp310-win_amd64.whl.metadata (7.7 kB)
# Collecting pandas
#   Downloading pandas-2.3.3-cp310-cp310-win_amd64.whl.metadata (19 kB)
# Collecting reportlab
#   Downloading reportlab-4.4.5-py3-none-any.whl.metadata (1.7 kB)
# Collecting numpy
#   Using cached numpy-2.2.6-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: charset-normalizer>=2.0.0 in d:\pycharmprojects\preparadorlattes\.venv\lib\site-packages (from pdfminer.six) (3.4.4)
# Collecting cryptography>=36.0.0 (from pdfminer.six)
#   Downloading cryptography-46.0.3-cp38-abi3-win_amd64.whl.metadata (5.7 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\pycharmprojects\preparadorlattes\.venv\lib\site-packages (from openai) (4.12.0)
# Collecting distro<2,>=1.7.0 (from openai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\pycharmprojects\preparadorlattes\.venv\lib\site-packages (from openai) (0.28.1)
# Collecting jiter<1,>=0.10.0 (from openai)
#   Downloading jiter-0.12.0-cp310-cp310-win_amd64.whl.metadata (5.3 kB)
# Collecting pydantic<3,>=1.9.0 (from openai)
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting sniffio (from openai)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting tqdm>4 (from openai)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: typing-extensions<5,>=4.11 in d:\pycharmprojects\preparadorlattes\.venv\lib\site-packages (from openai) (4.15.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in d:\pycharmprojects\preparadorlattes\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in d:\pycharmprojects\preparadorlattes\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in d:\pycharmprojects\preparadorlattes\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in d:\pycharmprojects\preparadorlattes\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\pycharmprojects\preparadorlattes\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->openai)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3,>=1.9.0->openai)
#   Downloading pydantic_core-2.41.5-cp310-cp310-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3,>=1.9.0->openai)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: packaging in d:\pycharmprojects\preparadorlattes\.venv\lib\site-packages (from faiss-cpu) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\pycharmprojects\preparadorlattes\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: tzdata>=2022.7 in d:\pycharmprojects\preparadorlattes\.venv\lib\site-packages (from pandas) (2025.2)
# Collecting pillow>=9.0.0 (from reportlab)
#   Using cached pillow-12.0.0-cp310-cp310-win_amd64.whl.metadata (9.0 kB)
# Requirement already satisfied: cffi>=2.0.0 in d:\pycharmprojects\preparadorlattes\.venv\lib\site-packages (from cryptography>=36.0.0->pdfminer.six) (2.0.0)
# Requirement already satisfied: pycparser in d:\pycharmprojects\preparadorlattes\.venv\lib\site-packages (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer.six) (2.23)
# Requirement already satisfied: six>=1.5 in d:\pycharmprojects\preparadorlattes\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: colorama in d:\pycharmprojects\preparadorlattes\.venv\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Downloading pdfminer_six-20251107-py3-none-any.whl (5.6 MB)
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    --------- ------------------------------ 1.3/5.6 MB 8.4 MB/s eta 0:00:01
#    ------------------ --------------------- 2.6/5.6 MB 7.9 MB/s eta 0:00:01
#    -------------------------- ------------- 3.7/5.6 MB 6.4 MB/s eta 0:00:01
#    ------------------------------- -------- 4.5/5.6 MB 5.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 5.0/5.6 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------  5.5/5.6 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------- 5.6/5.6 MB 4.6 MB/s eta 0:00:00
# Downloading openai-2.8.1-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    -------------------- ------------------- 0.5/1.0 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 3.2 MB/s eta 0:00:00
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.12.0-cp310-cp310-win_amd64.whl (204 kB)
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp310-cp310-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    --------------- ------------------------ 0.8/2.0 MB 2.2 MB/s eta 0:00:01
#    -------------------------- ------------- 1.3/2.0 MB 2.2 MB/s eta 0:00:01
#    ------------------------------- -------- 1.6/2.0 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 2.3 MB/s eta 0:00:00
# Downloading faiss_cpu-1.13.0-cp310-cp310-win_amd64.whl (18.7 MB)
#    ---------------------------------------- 0.0/18.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/18.7 MB ? eta -:--:--
#    -- ------------------------------------- 1.0/18.7 MB 2.8 MB/s eta 0:00:07
#    --- ------------------------------------ 1.6/18.7 MB 2.9 MB/s eta 0:00:06
#    ----- ---------------------------------- 2.4/18.7 MB 3.0 MB/s eta 0:00:06
#    ------ --------------------------------- 2.9/18.7 MB 2.9 MB/s eta 0:00:06
#    ------ --------------------------------- 3.1/18.7 MB 2.8 MB/s eta 0:00:06
#    ------- -------------------------------- 3.7/18.7 MB 2.6 MB/s eta 0:00:06
#    -------- ------------------------------- 3.9/18.7 MB 2.6 MB/s eta 0:00:06
#    --------- ------------------------------ 4.5/18.7 MB 2.5 MB/s eta 0:00:06
#    ---------- ----------------------------- 5.0/18.7 MB 2.5 MB/s eta 0:00:06
#    ----------- ---------------------------- 5.5/18.7 MB 2.5 MB/s eta 0:00:06
#    ------------ --------------------------- 5.8/18.7 MB 2.4 MB/s eta 0:00:06
#    ------------ --------------------------- 6.0/18.7 MB 2.4 MB/s eta 0:00:06
#    -------------- ------------------------- 6.6/18.7 MB 2.3 MB/s eta 0:00:06
#    --------------- ------------------------ 7.1/18.7 MB 2.3 MB/s eta 0:00:05
#    --------------- ------------------------ 7.3/18.7 MB 2.3 MB/s eta 0:00:05
#    ---------------- ----------------------- 7.9/18.7 MB 2.3 MB/s eta 0:00:05
#    ------------------ --------------------- 8.7/18.7 MB 2.4 MB/s eta 0:00:05
#    ------------------- -------------------- 9.2/18.7 MB 2.4 MB/s eta 0:00:04
#    -------------------- ------------------- 9.7/18.7 MB 2.5 MB/s eta 0:00:04
#    ---------------------- ----------------- 10.5/18.7 MB 2.5 MB/s eta 0:00:04
#    ------------------------ --------------- 11.3/18.7 MB 2.6 MB/s eta 0:00:03
#    ------------------------- -------------- 12.1/18.7 MB 2.6 MB/s eta 0:00:03
#    --------------------------- ------------ 12.8/18.7 MB 2.7 MB/s eta 0:00:03
#    ----------------------------- ---------- 13.6/18.7 MB 2.7 MB/s eta 0:00:02
#    ------------------------------- -------- 14.7/18.7 MB 2.8 MB/s eta 0:00:02
#    --------------------------------- ------ 15.5/18.7 MB 2.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 16.5/18.7 MB 2.9 MB/s eta 0:00:01
#    ------------------------------------ --- 17.0/18.7 MB 2.9 MB/s eta 0:00:01
#    ------------------------------------- -- 17.6/18.7 MB 2.9 MB/s eta 0:00:01
#    -------------------------------------- - 17.8/18.7 MB 2.9 MB/s eta 0:00:01
#    -------------------------------------- - 18.1/18.7 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------  18.4/18.7 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 18.7/18.7 MB 2.8 MB/s eta 0:00:00
# Using cached numpy-2.2.6-cp310-cp310-win_amd64.whl (12.9 MB)
# Downloading pandas-2.3.3-cp310-cp310-win_amd64.whl (11.3 MB)
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.3 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.3 MB 1.5 MB/s eta 0:00:08
#    -- ------------------------------------- 0.8/11.3 MB 1.5 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.3/11.3 MB 1.7 MB/s eta 0:00:06
#    ------ --------------------------------- 1.8/11.3 MB 1.9 MB/s eta 0:00:06
#    -------- ------------------------------- 2.4/11.3 MB 2.0 MB/s eta 0:00:05
#    --------- ------------------------------ 2.6/11.3 MB 2.0 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.1/11.3 MB 2.1 MB/s eta 0:00:04
#    ------------ --------------------------- 3.7/11.3 MB 2.1 MB/s eta 0:00:04
#    -------------- ------------------------- 4.2/11.3 MB 2.1 MB/s eta 0:00:04
#    ---------------- ----------------------- 4.7/11.3 MB 2.2 MB/s eta 0:00:04
#    ------------------ --------------------- 5.2/11.3 MB 2.2 MB/s eta 0:00:03
#    -------------------- ------------------- 5.8/11.3 MB 2.2 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.3/11.3 MB 2.3 MB/s eta 0:00:03
#    ------------------------ --------------- 7.1/11.3 MB 2.4 MB/s eta 0:00:02
#    --------------------------- ------------ 7.9/11.3 MB 2.5 MB/s eta 0:00:02
#    ------------------------------ --------- 8.7/11.3 MB 2.6 MB/s eta 0:00:02
#    --------------------------------- ------ 9.4/11.3 MB 2.6 MB/s eta 0:00:01
#    ------------------------------------ --- 10.2/11.3 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.3 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 2.8 MB/s eta 0:00:00
# Downloading reportlab-4.4.5-py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------- ----------------------- 0.8/2.0 MB 4.8 MB/s eta 0:00:01
#    ------------------------------------- -- 1.8/2.0 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 4.5 MB/s eta 0:00:00
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading cryptography-46.0.3-cp38-abi3-win_amd64.whl (3.5 MB)
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    ----------- ---------------------------- 1.0/3.5 MB 5.0 MB/s eta 0:00:01
#    -------------------------- ------------- 2.4/3.5 MB 4.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.6/3.5 MB 4.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.1/3.5 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 3.5/3.5 MB 3.1 MB/s eta 0:00:00
# Using cached pillow-12.0.0-cp310-cp310-win_amd64.whl (7.0 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: pytz, typing-inspection, tqdm, sniffio, pydantic-core, pillow, numpy, jiter, distro, annotated-types, reportlab, pydantic, pandas, faiss-cpu, cryptography, pdfminer.six, openai
#
#    ----------------------------------------  0/17 [pytz]
#    ----------------------------------------  0/17 [pytz]
#    ----------------------------------------  0/17 [pytz]
#    ----------------------------------------  0/17 [pytz]
#    ----------------------------------------  0/17 [pytz]
#    ----------------------------------------  0/17 [pytz]
#    ----------------------------------------  0/17 [pytz]
#    ----------------------------------------  0/17 [pytz]
#    ----------------------------------------  0/17 [pytz]
#    ----------------------------------------  0/17 [pytz]
#    ----------------------------------------  0/17 [pytz]
#    ----------------------------------------  0/17 [pytz]
#    ----------------------------------------  0/17 [pytz]
#    ----------------------------------------  0/17 [pytz]
#    -- -------------------------------------  1/17 [typing-inspection]
#    ---- -----------------------------------  2/17 [tqdm]
#    ---- -----------------------------------  2/17 [tqdm]
#    ---- -----------------------------------  2/17 [tqdm]
#    ---- -----------------------------------  2/17 [tqdm]
#    ---- -----------------------------------  2/17 [tqdm]
#    ---- -----------------------------------  2/17 [tqdm]
#    ---- -----------------------------------  2/17 [tqdm]
#    ---- -----------------------------------  2/17 [tqdm]
#    ------- --------------------------------  3/17 [sniffio]
#    ------- --------------------------------  3/17 [sniffio]
#    --------- ------------------------------  4/17 [pydantic-core]
#    --------- ------------------------------  4/17 [pydantic-core]
#    --------- ------------------------------  4/17 [pydantic-core]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    ----------- ----------------------------  5/17 [pillow]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    -------------- -------------------------  6/17 [numpy]
#    ------------------ ---------------------  8/17 [distro]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ----------------------- ---------------- 10/17 [reportlab]
#    ------------------------- -------------- 11/17 [pydantic]
#    ------------------------- -------------- 11/17 [pydantic]
#    ------------------------- -------------- 11/17 [pydantic]
#    ------------------------- -------------- 11/17 [pydantic]
#    ------------------------- -------------- 11/17 [pydantic]
#    ------------------------- -------------- 11/17 [pydantic]
#    ------------------------- -------------- 11/17 [pydantic]
#    ------------------------- -------------- 11/17 [pydantic]
#    ------------------------- -------------- 11/17 [pydantic]
#    ------------------------- -------------- 11/17 [pydantic]
#    ------------------------- -------------- 11/17 [pydantic]
#    ------------------------- -------------- 11/17 [pydantic]
#    ------------------------- -------------- 11/17 [pydantic]
#    ------------------------- -------------- 11/17 [pydantic]
#    ------------------------- -------------- 11/17 [pydantic]
#    ------------------------- -------------- 11/17 [pydantic]
#    ------------------------- -------------- 11/17 [pydantic]
#    ------------------------- -------------- 11/17 [pydantic]
#    ------------------------- -------------- 11/17 [pydantic]
#    ------------------------- -------------- 11/17 [pydantic]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ---------------------------- ----------- 12/17 [pandas]
#    ------------------------------ --------- 13/17 [faiss-cpu]
#    ------------------------------ --------- 13/17 [faiss-cpu]
#    ------------------------------ --------- 13/17 [faiss-cpu]
#    ------------------------------ --------- 13/17 [faiss-cpu]
#    ------------------------------ --------- 13/17 [faiss-cpu]
#    ------------------------------ --------- 13/17 [faiss-cpu]
#    ------------------------------ --------- 13/17 [faiss-cpu]
#    ------------------------------ --------- 13/17 [faiss-cpu]
#    ------------------------------ --------- 13/17 [faiss-cpu]
#    -------------------------------- ------- 14/17 [cryptography]
#    -------------------------------- ------- 14/17 [cryptography]
#    -------------------------------- ------- 14/17 [cryptography]
#    -------------------------------- ------- 14/17 [cryptography]
#    -------------------------------- ------- 14/17 [cryptography]
#    -------------------------------- ------- 14/17 [cryptography]
#    -------------------------------- ------- 14/17 [cryptography]
#    -------------------------------- ------- 14/17 [cryptography]
#    ----------------------------------- ---- 15/17 [pdfminer.six]
#    ----------------------------------- ---- 15/17 [pdfminer.six]
#    ----------------------------------- ---- 15/17 [pdfminer.six]
#    ----------------------------------- ---- 15/17 [pdfminer.six]
#    ----------------------------------- ---- 15/17 [pdfminer.six]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ------------------------------------- -- 16/17 [openai]
#    ---------------------------------------- 17/17 [openai]
#
# Successfully installed annotated-types-0.7.0 cryptography-46.0.3 distro-1.9.0 faiss-cpu-1.13.0 jiter-0.12.0 numpy-2.2.6 openai-2.8.1 pandas-2.3.3 pdfminer.six-20251107 pillow-12.0.0 pydantic-2.12.5 pydantic-core-2.41.5 pytz-2025.2 reportlab-4.4.5 sniffio-1.3.1 tqdm-4.67.1 typing-inspection-0.4.2
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in d:\pycharmprojects\preparadorlattes\.venv\lib\site-packages (1.2.1)
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import glob
import numpy as np
import pandas as pd
from typing import List, Dict, Tuple
from dotenv import load_dotenv

# Bibliotecas de PDF e Texto
from pdfminer.high_level import extract_text
from io import StringIO

# OpenAI e Vetores
from openai import OpenAI
import faiss

# Relatórios
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas

# Load environment variables from .env file
load_dotenv()

# --- CONFIGURAÇÃO ---
# Substitua pela sua chave API ou defina na variável de ambiente
os.environ["OPENAI_API_KEY"] = os.getenv('OPENAI_API_KEY')
client = OpenAI()

DIRS = {
    "LATTES": "D:/PycharmProjects/PreparadorLattes/lattes/lattes.pdf",  # Caminho do arquivo Lattes
    "CERTIFICADOS": "D:/PycharmProjects/PreparadorLattes/certificados/" # Pasta com os PDFs
}

# Modelo de Embedding (mais barato e eficiente para busca)
EMBEDDING_MODEL = "text-embedding-3-small"
# Modelo de LLM para raciocínio
LLM_MODEL = "gpt-4o"

# %%
def extract_text_from_pdf(pdf_path: str) -> str:
    """Extrai texto bruto de um arquivo PDF."""
    print(f"Lendo o arquivo PDF: {pdf_path}")
    try:
        text = extract_text(pdf_path)
        if text.strip():
            print(
                f"Texto extraído com sucesso do arquivo: {pdf_path[:50]}...")  # Exibir os primeiros 50 caracteres do caminho
        else:
            print(f"Arquivo aparentemente vazio: {pdf_path}")
        return text
    except Exception as e:
        print(f"Erro ao ler {pdf_path}: {e}")
        return ""

def chunk_lattes_data(lattes_text: str) -> List[str]:
    """
    Quebra o texto do Lattes em itens verificáveis.
    Estratégia: Quebrar por linhas duplas ou blocos significativos.
    Filtra linhas muito curtas (cabeçalhos, números de página).
    """
    print("Iniciando o processo de chunking do Lattes...")
    raw_lines = [line.strip() for line in lattes_text.split('\n') if line.strip()]
    print(f"Total de linhas no texto Lattes: {len(raw_lines)}")

    items = []
    buffer = ""

    for line in raw_lines:
        if len(line) < 4:
            print(f"Linha ignorada (muito curta): '{line}'")
            continue
        buffer += " " + line
        if len(buffer) > 150:
            items.append(buffer.strip())
            print(f"Novo item detectado: {buffer[:50]}...")  # Exibir os 50 primeiros caracteres
            buffer = ""

    if buffer:
        items.append(buffer.strip())
        print(f"Adicionando último item detectado: {buffer[:50]}...")

    print(f"Total de itens após chunking: {len(items)}")
    return items

def load_certificates(folder_path: str) -> List[Dict]:
    """Lê todos os PDFs da pasta de certificados."""
    print(f"Procurando arquivos PDF na pasta: {folder_path}")
    certificates = []
    files = glob.glob(os.path.join(folder_path, "*.pdf"))
    print(f"Total de arquivos encontrados: {len(files)}")

    for idx, file_path in enumerate(files, start=1):
        filename = os.path.basename(file_path)
        print(f"Lendo ({idx}/{len(files)}): {filename}")

        content = extract_text_from_pdf(file_path)

        if len(content) < 50:
            print(f"Aviso: O arquivo '{filename}' parece vazio ou pode ser um PDF escaneado.")

        certificates.append({
            "filename": filename,
            "content": content,
            "path": file_path,
        })

    print(f"Total de certificados processados: {len(certificates)}")
    return certificates

# %%
def get_embedding(text: str, model=EMBEDDING_MODEL):
    """Gera o vetor numérico para um texto."""
    text = text.replace("\n", " ")
    # Truncate to fit limits if necessary, though simple texts are usually fine
    return client.embeddings.create(input=[text], model=model).data[0].embedding

def create_faiss_index(certificates: List[Dict]):
    """Cria o índice FAISS com os conteúdos dos certificados."""
    print("Gerando embeddings para os certificados...")
    embeddings = []
    valid_indices = []

    for idx, cert in enumerate(certificates):
        if not cert['content'].strip():
            continue

        emb = get_embedding(cert['content'])
        embeddings.append(emb)
        valid_indices.append(idx)

    if not embeddings:
        raise ValueError("Nenhum conteúdo de texto extraído dos certificados.")

    # Converte para numpy array float32 (exigido pelo FAISS)
    dataset = np.array(embeddings).astype("float32")

    # Dimensão do vetor (1536 para text-embedding-3-small)
    dimension = dataset.shape[1]

    # Cria índice L2 (Euclidiano)
    index = faiss.IndexFlatL2(dimension)
    index.add(dataset)

    return index, valid_indices

# %%
def verify_items(lattes_items: List[str], certificates: List[Dict], index, valid_cert_indices):
    results = []
    matched_certificates_files = set()

    print(f"Iniciando verificação de {len(lattes_items)} itens do Lattes...")

    for lattes_item in lattes_items:
        # 1. Busca Vetorial: Achar o candidato mais provável
        query_emb = np.array([get_embedding(lattes_item)]).astype("float32")
        k = 1 # Top 1 candidato
        distances, indices = index.search(query_emb, k)

        # Recupera o certificado sugerido pelo FAISS
        cert_idx_in_list = valid_cert_indices[indices[0][0]]
        candidate_cert = certificates[cert_idx_in_list]

        # 2. Validação Lógica com GPT-4 (LLM como Juiz)
        # O prompt é crucial aqui para evitar alucinações
        prompt = f"""
        Você é um auditor acadêmico rigoroso.

        ITEM DO CURRÍCULO LATTES:
        "{lattes_item}"

        CONTEÚDO DO CERTIFICADO (Arquivo: {candidate_cert['filename']}):
        "{candidate_cert['content'][:2000]}" ... (truncado)

        A pergunta: O conteúdo do certificado comprova EXATAMENTE ou PARCIALMENTE o item do currículo?
        Responda APENAS com um formato JSON: {{"match": true/false, "reason": "explicação curta"}}
        Se for uma correspondência fraca ou assunto diferente, responda false.
        """

        try:
            response = client.chat.completions.create(
                model=LLM_MODEL,
                messages=[{"role": "user", "content": prompt}],
                response_format={"type": "json_object"}
            )
            import json
            evaluation = json.loads(response.choices[0].message.content)

            is_match = evaluation.get('match', False)
            reason = evaluation.get('reason', 'Sem justificativa')

            status = "CONFORME" if is_match else "NÃO CONFORME (Certificado não encontrado ou incompatível)"
            matched_file = candidate_cert['filename'] if is_match else None

            if is_match:
                matched_certificates_files.add(candidate_cert['filename'])

            results.append({
                "Lattes_Item": lattes_item[:100] + "...", # Truncar para visualização
                "Status": status,
                "Certificado_Sugerido": candidate_cert['filename'],
                "LLM_Justificativa": reason
            })

        except Exception as e:
            print(f"Erro na validação LLM: {e}")

    return pd.DataFrame(results), matched_certificates_files

# %%
# 1. Executar o Pipeline
print("--- Lendo Lattes ---")
lattes_text = extract_text_from_pdf(DIRS["LATTES"])
lattes_items = chunk_lattes_data(lattes_text)

print("--- Lendo Certificados ---")
certs_data = load_certificates(DIRS["CERTIFICADOS"])

# Se não houver certificados ou lattes, parar
if not lattes_items or not certs_data:
    print("Erro: Faltam dados para processar.")
else:
    # 2. Indexação
    index, valid_indices = create_faiss_index(certs_data)

    # 3. Verificação (Lattes -> Certificados)
    df_results, matched_files = verify_items(lattes_items, certs_data, index, valid_indices)

    # 4. Verificação Inversa (Certificados -> Lattes)
    # Quais certificados estão na pasta mas não foram usados para validar nada?
    all_files = set([c['filename'] for c in certs_data])
    orphan_certs = all_files - matched_files

    # Exibir resultados na tela
    print("\n=== RESUMO DA ANÁLISE ===")
    print(df_results['Status'].value_counts())
    print(f"\nCertificados Sobrando (Órfãos): {len(orphan_certs)}")

    # 5. Geração do Relatório PDF
    def generate_pdf_report(dataframe, orphans, filename="Relatorio_Conformidade.pdf"):
        c = canvas.Canvas(filename, pagesize=letter)
        width, height = letter
        y = height - 40

        c.setFont("Helvetica-Bold", 16)
        c.drawString(30, y, "Relatório de Auditoria Lattes")
        y -= 30

        c.setFont("Helvetica", 10)
        c.drawString(30, y, "Itens analisados do Currículo Lattes e seus respectivos status:")
        y -= 20

        # Loop pelos itens (simplificado para o exemplo)
        for _, row in dataframe.iterrows():
            if y < 100: # Nova página
                c.showPage()
                y = height - 40
                c.setFont("Helvetica", 10)

            status_color = (0, 0.5, 0) if "CONFORME" in row['Status'] else (1, 0, 0) # Verde ou Vermelho

            c.setFillColorRGB(0, 0, 0)
            c.drawString(30, y, f"Item: {row['Lattes_Item']}")
            y -= 12

            c.setFillColorRGB(*status_color)
            c.drawString(30, y, f"Status: {row['Status']}")
            y -= 12

            c.setFillColorRGB(0.3, 0.3, 0.3)
            c.drawString(30, y, f"Justificativa: {row['LLM_Justificativa']}")
            y -= 25 # Espaço entre itens

        # Seção de Órfãos
        if y < 150: c.showPage(); y = height - 40

        y -= 20
        c.setFillColorRGB(0, 0, 0)
        c.setFont("Helvetica-Bold", 12)
        c.drawString(30, y, "Certificados presentes na pasta mas NÃO citados no Lattes:")
        y -= 20
        c.setFont("Helvetica", 10)

        for orphan in orphans:
            c.drawString(40, y, f"- {orphan}")
            y -= 15

        c.save()
        print(f"Relatório gerado com sucesso: {filename}")

    # Gerar
    generate_pdf_report(df_results, orphan_certs)
# Out:
# --- Lendo Lattes ---
# Lendo o arquivo PDF: D:/PycharmProjects/PreparadorLattes/lattes/lattes.pdf
# Texto extraído com sucesso do arquivo: D:/PycharmProjects/PreparadorLattes/lattes/lattes....
# Iniciando o processo de chunking do Lattes...
# Total de linhas no texto Lattes: 1111
# Novo item detectado:  Paulo Victor dos Santos Endereço para acessar est...
# Novo item detectado:  Sou um profissional com mais de 16 anos de experi...
# Novo item detectado:  habilidades de comunicação, pensamento crítico e ...
# Novo item detectado:  novos  desafios.  Meu  objetivo  é  continuar  ap...
# Novo item detectado:  espiritual,  buscando  profundidade  em  minhas  ...
# Novo item detectado:  mundo.Minha expertise inclui o desenvolvimento e ...
# Novo item detectado:  Também tenho conhecimento em linguagens como SQL,...
# Novo item detectado:  acadêmica  inclui  um  doutorado  em  Engenharia ...
# Novo item detectado:  e  um  bacharelado  em  Análise  de  Sistemas  pe...
# Novo item detectado:  Nome em citações bibliográficas SANTOS,  P.  V.;S...
# Linha ignorada (muito curta): '?'
# Novo item detectado:  PAULO;Santos, Paulo;VICTOR,  PAULO;SANTOS,  PAULO...
# Novo item detectado:  https://orcid.org/0000-0002-8267- País de Naciona...
# Novo item detectado:  Universidade  Federal  de  Goiás,  UFG, Brasil. T...
# Novo item detectado:  Ano de obtenção: 2024. Orientador:  Wesley Pachec...
# Novo item detectado:  Universidade  Federal  de  Goiás,  UFG, Brasil. T...
# Linha ignorada (muito curta): 'às'
# Novo item detectado:  para concessionárias  de distribuição  , Ano de O...
# Novo item detectado:  Graduação em Análise de Sistemas. Universidade UN...
# Novo item detectado:  Formação Complementar 2018 - 2018 Compreensão  or...
# Linha ignorada (muito curta): 'aos'
# Linha ignorada (muito curta): 'de'
# Novo item detectado:  Introdução Geoprocessamento  utilizando  Python  ...
# Novo item detectado:  ArcGIS  4:  Compartilhando  Conteúdo  na Web (10....
# Novo item detectado:  FOR JAVA E .NET. (Carga horária: 40h). Imagem  Ge...
# Novo item detectado:  Vínculo institucional 2020 - 2021 Vínculo: , Enqu...
# Novo item detectado:  Linhas de pesquisa Inteligência Artificial Univer...
# Novo item detectado:  Funcional: Pesquisador Outras informações Membro ...
# Linha ignorada (muito curta): 'VLM'
# Novo item detectado:  Linhas de pesquisa Cientista de dados com modelos...
# Novo item detectado:  disciplina de Programação. 02/2016 - 06/2016 Está...
# Novo item detectado:  Universidade Tecnológica Federal do Paraná, UTFPR...
# Novo item detectado:  Companhia Energética de Goiás, CELG, Brasil. Vínc...
# Novo item detectado:  Carga horária: 40 Vínculo institucional 2012 - 20...
# Novo item detectado:  Softplan Planejamento e Sistemas, SOFTPLAN, Brasi...
# Novo item detectado:  Universidade Federal do Tocantins, UFT, Brasil. V...
# Linha ignorada (muito curta): ','
# Linha ignorada (muito curta): 'do'
# Novo item detectado:  horária: 40 Atividades 07/2007 - 07/2008 técnicos...
# Novo item detectado:  ao usuário. Indra Software Labs, INDRA, Brasil. V...
# Linha ignorada (muito curta): '40'
# Novo item detectado:  Otimize-Ti Fabrica de Softwares, OTIMIZE-TI, Bras...
# Novo item detectado:  Carga horária: 44 Outras informações Desenvolvedo...
# Novo item detectado:  outros.  Conhecimento entre Hospital Israelita Al...
# Linha ignorada (muito curta): '1.'
# Linha ignorada (muito curta): '2.'
# Novo item detectado:  horária: 40 Outras informações Cientista de dados...
# Linha ignorada (muito curta): 'VLM'
# Novo item detectado:  Inteligência Artificial Projetos de pesquisa 2025...
# Novo item detectado:  Ressonância Magnética Situação:  Em  andamento;  ...
# Novo item detectado:  Integrante / Paulo Marcio Borges Daniel - Integra...
# Linha ignorada (muito curta): '-'
# Novo item detectado:  Situação:  Em  andamento;  Natureza: Pesquisa. / ...
# Novo item detectado:  Jeferson  José  de  Lima  -  Integrante  / FRIEDA...
# Novo item detectado:  Navegando pelas Mudanças Urbanas Situação:  Em  a...
# Linha ignorada (muito curta): '-'
# Novo item detectado:  Coordenador / Marcella Scoczynski Ribeiro Martins...
# Novo item detectado:  FERNANDA  OLIVEIRA  DE  FIGUEIREDO  - Integrante ...
# Novo item detectado:  utilizando inteligência artificial Situação: Conc...
# Novo item detectado:  Integrante  /  Marcio  Rodrigues  da  Cunha Reis ...
# Novo item detectado:  -  Coordenador 2020 - 2021 Inteligência  Artifici...
# Novo item detectado:  algoritmo  de  desagregação  de  consumo de  ener...
# Linha ignorada (muito curta): 'do'
# Novo item detectado:  máquinas  e  equipamentos,  reduzindo  a complexi...
# Novo item detectado:  tem  como principal  função  permitir  uma  mediç...
# Novo item detectado:  do  mapeamento Integrantes:  Paulo  Victor  dos  ...
# Novo item detectado:  2020 - Atual DETECÇÃO  DO  COVID-19  ATRAVÉS  DE ...
# Novo item detectado:  análise  de  raio-X  de  pulmão  usando metodolog...
# Novo item detectado:  e parceria com a Universidade Federal de Goiás, A...
# Linha ignorada (muito curta): 'de'
# Linha ignorada (muito curta): '/'
# Novo item detectado:  Alunos  envolvidos:  Graduação:  (4)  / Doutorado...
# Linha ignorada (muito curta): '-'
# Linha ignorada (muito curta): '-'
# Novo item detectado:  Coordenador / Marcella Scoczynski Ribeiro Sthefan...
# Novo item detectado:  Camargo  -  Integrante  /  Wesley  Pacheco Calixt...
# Linha ignorada (muito curta): 'DE'
# Novo item detectado:  da Cruz Júnior - Integrante. 2018 - 2022 INTEGRAD...
# Linha ignorada (muito curta): 'DE'
# Linha ignorada (muito curta): 'do'
# Novo item detectado:  CAMPO  E  MUDANÇAS  TOPOLÓGICAS VISANDO REDES INT...
# Linha ignorada (muito curta): 'de'
# Novo item detectado:  integrada  aos  sistemas  da  COPEL  DIS para res...
# Linha ignorada (muito curta): 'de'
# Linha ignorada (muito curta): 'do'
# Novo item detectado:  operação  em  tempo  real,  que  atuará  nas cinc...
# Novo item detectado:  localização  e falta;  3) autorreconfiguração;  4...
# Novo item detectado:  Situação: Concluído; Natureza: Pesquisa. isolação...
# Novo item detectado:  Integrante /  GUILHERME  ALBERTO SOUSA  RIBEIRO  ...
# Novo item detectado:  /  TELMA  WOERLE  DE  LIMA  SOARE  - Integrante  ...
# Linha ignorada (muito curta): '/'
# Linha ignorada (muito curta): '-'
# Linha ignorada (muito curta): '-'
# Novo item detectado:  FERREIRA  DE  LIMA VANDERLEI  ZARNICINSKI  -  Int...
# Linha ignorada (muito curta): 'e'
# Novo item detectado:  Rede de Distribuição Quanto às Violações de Tensã...
# Novo item detectado:  S.A. ferramenta desenvolver computacional  para  ...
# Novo item detectado:  no  Módulo  nº  8  (Qualidade  de  Energia Elétri...
# Novo item detectado:  tensão da concessionária, possibilitando a mesma ...
# Novo item detectado:  previstas  em  lei,  as  quais  sem  controle efe...
# Novo item detectado:  Pesquisa.  Alunos  envolvidos:  Graduação: (4)  /...
# Novo item detectado:  Situação: Concluído; Natureza: Pesquisa. Alunos  ...
# Linha ignorada (muito curta): 'de'
# Linha ignorada (muito curta): '-'
# Novo item detectado:  poderiam Integrantes:  Paulo  Victor  dos  Santos...
# Novo item detectado:  Reis  -  Integrante  /  Viviane  Margarida Gomes ...
# Novo item detectado:  de  rede  baseado  em  imagens  utilizando visão ...
# Linha ignorada (muito curta): 'de'
# Novo item detectado:  Geográficas,  auxiliando  na  identificando regiõ...
# Novo item detectado:  mesmo  a  qualidade  da  energia  elétrica fornec...
# Novo item detectado:  Mestrado acadêmico: (2) . Integrantes:  Paulo  Vi...
# Novo item detectado:  Oliveira  -  Integrante  /  Anderson  da  Silva S...
# Novo item detectado:  Potência  e  Curto  Circuito  no  Ambiente  de Ba...
# Linha ignorada (muito curta): 'e'
# Novo item detectado:  Sistema  de  Distribuição  da  CELG;  Projeto de ...
# Linha ignorada (muito curta): 'de'
# Linha ignorada (muito curta): '-'
# Novo item detectado:  - LINGUAGENS DE PROGRAMAÇÃO. Situação: Concluído;...
# Linha ignorada (muito curta): 'of'
# Linha ignorada (muito curta): '1.'
# Linha ignorada (muito curta): '2.'
# Novo item detectado:  /  Colemar  Arruda Revisor de periódico 2021 - At...
# Linha ignorada (muito curta): 'da'
# Novo item detectado:  Área: Ciência da Computação. Grande área: Ciência...
# Linha ignorada (muito curta): 'Lê'
# Linha ignorada (muito curta): 'Lê'
# Novo item detectado:  Modelos Analíticos e de Simulação. Compreende Raz...
# Novo item detectado:  Razoavelmente, Fala Razoavelmente, Prêmios e títu...
# Novo item detectado:  Prêmio destaque de Pesquisa e Inovação, Otimize-t...
# Linha ignorada (muito curta): '1.'
# Linha ignorada (muito curta): '2.'
# Linha ignorada (muito curta): '3.'
# Linha ignorada (muito curta): ';'
# Linha ignorada (muito curta): ';'
# Novo item detectado:  Ordenar por Ordem Cronológica Barbosa CAMARGO, T....
# Linha ignorada (muito curta): 'Luz'
# Linha ignorada (muito curta): 'V.'
# Linha ignorada (muito curta): 'P.'
# Novo item detectado:  identifying in  myocardial  perfusion scintigraph...
# Novo item detectado:  PRÔA DALLE ; ASHIHARA, CAROLINA ; NAWA, RICARDO K...
# Novo item detectado:  SILVA  ;  CARMONA,  MARIA  JOSÉ  CARVALHO  ;  CHA...
# Novo item detectado:  for  anesthesiologists:  a literature NOGUEIRA,  ...
# Novo item detectado:  CARVALHAES, FELIPE BRAZAO F. ; REIS, MARCIO RODRI...
# Novo item detectado:  VIVIANE M. GOMES ; COIMBRA, ANTONIO PAULO ; CALIX...
# Linha ignorada (muito curta): '1 |'
# Linha ignorada (muito curta): '1'
# Linha ignorada (muito curta): '4.'
# Linha ignorada (muito curta): '5.'
# Linha ignorada (muito curta): '6.'
# Linha ignorada (muito curta): '7.'
# Linha ignorada (muito curta): '8.'
# Novo item detectado:  images:  Pilot  study.  PLoS  One ,  v.  20,  p. ...
# Novo item detectado:  OLIVEIRA ; RIBEIRO, M. S. . Transcriptomic Patter...
# Novo item detectado:  SANTOS, P. V.; RIBEIRO, M. S. ; Wesley Pacheco Ca...
# Linha ignorada (muito curta): '19'
# Novo item detectado:  , v. 1, p. 1- 1, 2024. Citações: 27 | SANTOS,  P....
# Linha ignorada (muito curta): '1 |'
# Novo item detectado:  Loureiro  ;  Wesley  Pacheco  Calixto  .  Unsuper...
# Linha ignorada (muito curta): '1'
# Novo item detectado:  PACHECO, V. M. G. ; PAIVA, J. P. Q. ; FURRIEL, B....
# Novo item detectado:  S. A. ; LOUREIRO, R. M. ; CALIXTO, W. P. . Pilot ...
# Linha ignorada (muito curta): '1'
# Novo item detectado:  , v. 1, p. 1, 2024. Citações: SILVA,  LUAN  OLIVE...
# Novo item detectado:  VICTOR  DOS  ;  MENDES,  GIOVANNA  DE  SOUZA  ;  ...
# Novo item detectado:  RAFAEL  MAFFEI  ;  CALIXTO,  WESLEY  PACHECO  .  ...
# Linha ignorada (muito curta): '6 |'
# Linha ignorada (muito curta): '1'
# Linha ignorada (muito curta): '9.'
# Linha ignorada (muito curta): '10.'
# Linha ignorada (muito curta): '11.'
# Linha ignorada (muito curta): '12.'
# Linha ignorada (muito curta): '1.'
# Linha ignorada (muito curta): '2.'
# Novo item detectado:  ,  v.  19,  p.  e0305839,  2024.  Citações: pulmo...
# Novo item detectado:  VICTOR  ;  DA  CRUZ,  GELSON  ;  MOUSAVIRAD,  SEY...
# Linha ignorada (muito curta): '7 |'
# Linha ignorada (muito curta): '7'
# Linha ignorada (muito curta): 'for'
# Novo item detectado:  Cybernetics , v. sn, p. sn, 2022. Citações: singl...
# Novo item detectado:  VICTOR  F.  ;  BULGARELLI,  LUCAS  ;  LEE,  HENRI...
# Novo item detectado:  TELES, GUSTAVO B. S. ; SZARF, GILBERTO ; POLLARD,...
# Linha ignorada (muito curta): ','
# Linha ignorada (muito curta): '32'
# Novo item detectado:  v. 9, p. 487, 2022. Citações: 25 | VILELA JUNIOR,...
# Linha ignorada (muito curta): '4 |'
# Linha ignorada (muito curta): '4'
# Novo item detectado:  CALIXTO, WESLEY P. . Analysis and Adequacy Method...
# Novo item detectado:  JÚNIOR,  WAGNER  A.  ;  REIS,  MÁRCIO  R.  C.  ; ...
# Linha ignorada (muito curta): ','
# Linha ignorada (muito curta): '1 |'
# Linha ignorada (muito curta): '1'
# Novo item detectado:  Generation  Photovoltaic  to  Adjust  Voltage  Le...
# Novo item detectado:  P.  V.  ;  Silva,  Brunna  Carolinne  Rocha  ;  M...
# Novo item detectado:  BIDIRECIONAL  EM  LÍNGUA  DE  SINAIS.  Pensando  ...
# Linha ignorada (muito curta): 'NA'
# Novo item detectado:  AUXÍLIO PARA Paulo,  Artur  ;  Filho,  Fabiano  ;...
# Novo item detectado:  Mendes, Giovanna ; de Paiva, Joselisa ; Reis, Már...
# Novo item detectado:  Science.  0ed.:  Springer  Nature  Switzerland,  ...
# Novo item detectado:  ; ORTIZ, THIAGO ; VICTOR, PAULO ; Mendes, Giovann...
# Novo item detectado:  Classification on  Computed Tomography Angiograph...
# Novo item detectado:  2024,  Athens.  2024  IEEE  International  Sympos...
# Novo item detectado:  PAULO  ;  DOS  SANTOS  LIMA,  HERON  OLIVEIRA  ; ...
# Novo item detectado:  processes:  A  case  study  in  a  petrochemical ...
# Novo item detectado:  Conference on Computational Intelligence (LA-CCI)...
# Linha ignorada (muito curta): 'In:'
# Novo item detectado:  GONÇALVES,  CRISTHIANE  ;  PACHECO  CALIXTO,  WES...
# Novo item detectado:  GECCO '24 Companion: Genetic and Evolutionary Com...
# Linha ignorada (muito curta): '1.'
# Linha ignorada (muito curta): '2.'
# Linha ignorada (muito curta): '3.'
# Linha ignorada (muito curta): '4.'
# Novo item detectado:  Conference Companion. p. 2091. SIMM, VINICIUS SYL...
# Novo item detectado:  FIGUEIREDO,  MARIA  FERNANDA  OLIVEIRA  ;  PREMEB...
# Novo item detectado:  SCOCZYNSKI, MARCELLA . Polyp Segmentation in Colo...
# Linha ignorada (muito curta): '5.'
# Linha ignorada (muito curta): '6.'
# Linha ignorada (muito curta): '7.'
# Linha ignorada (muito curta): '1.'
# Novo item detectado:  International  Conference  on IEEE 2023  15th App...
# Novo item detectado:  TAVARES  ;  SIMM,  VINICIUS  SYLVESTRE  ;  MELLO,...
# Novo item detectado:  PREMEBIDA,  STHEFANIE  MONICA  ;  DOS  SANTOS,  P...
# Novo item detectado:  Colonoscopy  Images  Using  a  Vision  Transforme...
# Novo item detectado:  Industry Applications (INDUSCON), 2023. p. 627. I...
# Novo item detectado:  SANTOS,  PAULO  ;  PREMEBIDA,  STHEFANIE  MONICA ...
# Novo item detectado:  ROMMEL ; PACHECO, WESLEY CALIXTO ; ROCHA, CLEOMAR...
# Novo item detectado:  practical Deep Learning approach to assist COVID-...
# Novo item detectado:  Temuco.  2021 IEEE  Latin  American  Conference  ...
# Novo item detectado:  VIVIANE  M.  ;  SILVA,  ALAN  H.  F.  ;  FREITAS,...
# Novo item detectado:  M. ; ALVES, AYLTON J. ; SILVA, LAIS F. A. ; CALIX...
# Novo item detectado:  Scientific  Conference  on  Electric  Power  Engi...
# Novo item detectado:  Resumos publicados em anais de congressos PREMEBI...
# Linha ignorada (muito curta): '.'
# Novo item detectado:  EXPLAINABLE  DEEP  LEARNING  FOR  MALARIA  DIAGNO...
# Linha ignorada (muito curta): '2.'
# Linha ignorada (muito curta): '3.'
# Linha ignorada (muito curta): '4.'
# Linha ignorada (muito curta): '5.'
# Linha ignorada (muito curta): '6.'
# Novo item detectado:  Proceedings  of  the  21st  Brazilian  Congress  ...
# Novo item detectado:  PAULO  V.  ;  MARIA  FERNANDA  OLIVEIRA  DE  FIGU...
# Novo item detectado:  patterns  in  breast  cancer  patients..  In:  20...
# Novo item detectado:  SEIXAS, MONIQUE BORGES ; PADRE, N. S. ; RIBEIRO, ...
# Novo item detectado:  LIMA,  HERON  OLIVEIRA  .  MODELO  DE  CLASSIFICA...
# Novo item detectado:  In: Escola Paranaense de Bioinformática, 2024, Lo...
# Novo item detectado:  ;  SEIXAS,  MONIQUE  BORGES  ;  SIMM,  VINICIUS  ...
# Novo item detectado:  DOS  SANTOS,  PAULO  V.  ;  CALIXTO,  W.  P.  ;  ...
# Novo item detectado:  MECHANISM.  In:  X-Meeting  /  BSB  2023,  2023, ...
# Novo item detectado:  VINICIUS SYLVESTRE ; DE SOUZA, JOAO PEDRO BUSNARD...
# Novo item detectado:  DOS  SANTOS,  PAULO  V.  ;  CALIXTO,  W.  P.  ;  ...
# Novo item detectado:  Curitiba.  X-Meeting  presentations.  Curitiba:  ...
# Novo item detectado:  .  Feature  Selection  Method  AUC-Based  with RO...
# Linha ignorada (muito curta): '1.'
# Linha ignorada (muito curta): '2.'
# Linha ignorada (muito curta): '3.'
# Linha ignorada (muito curta): '4.'
# Linha ignorada (muito curta): '5.'
# Linha ignorada (muito curta): '6.'
# Linha ignorada (muito curta): '7.'
# Linha ignorada (muito curta): '8.'
# Novo item detectado:  (ICEET),  2021,  Istanbul.  2021  International  ...
# Linha ignorada (muito curta): 'de'
# Linha ignorada (muito curta): 'do'
# Novo item detectado:  advocacia.  2025.  (Apresentação  de  Trabalho/Co...
# Novo item detectado:  (Apresentação amanhã. 2025. DOS  SANTOS,  PAULO  ...
# Novo item detectado:  (Apresentação de Trabalho/Conferência ou palestra...
# Novo item detectado:  (Apresentação de Trabalho/Conferência ou palestra...
# Novo item detectado:  (Apresentação de Trabalho/Conferência ou palestra...
# Novo item detectado:  Tratamento.  2024.  (Apresentação  de  Trabalho/C...
# Novo item detectado:  SANTOS,  P.  V..  Palestra:  Uso  de  Inteligênci...
# Linha ignorada (muito curta): '9.'
# Linha ignorada (muito curta): '1.'
# Linha ignorada (muito curta): '2.'
# Novo item detectado:  SANTOS,  P.  V..  Palestra:  Arquitetura  otimiza...
# Novo item detectado:  Produção técnica Programas de computador sem regi...
# Novo item detectado:  tomography. 2024. SANTOS,  P.  V..  Inteligência ...
# Novo item detectado:  A Confirmação do status de um pedido de patentes ...
# Novo item detectado:  SANTOS, P. V.. PrimeErp. 2010, Brasil. registro: ...
# Novo item detectado:  10/10/2010; Comercialização: 01/01/2013. Inovação...
# Linha ignorada (muito curta): '1.'
# Linha ignorada (muito curta): '2.'
# Novo item detectado:  INPI  -  Instituto  Nacional  da  Propriedade  In...
# Linha ignorada (muito curta): '1.'
# Linha ignorada (muito curta): '2.'
# Linha ignorada (muito curta): '1.'
# Linha ignorada (muito curta): '1.'
# Novo item detectado:  Mestrado Marcella  Scoczynski  Ribeiro  Martins; ...
# Novo item detectado:  SANTOS  PADRE.  ANÁLISE  DE  PADRÕES  TRANSCRIPTÔ...
# Novo item detectado:  Federal do Paraná. Marcella  Scoczynski  Ribeiro ...
# Novo item detectado:  PARA PREDIÇÃO DE VARIÁVEIS DE PROCESSOS INDUSTRIA...
# Novo item detectado:  Qualificações de Doutorado RIBEIRO, G. A. S.; Ant...
# Novo item detectado:  PAULO VICTOR DOS; Gelson da Cruz Junior. Particip...
# Novo item detectado:  IDENTIFICAÇÃO  DE  CARGAS  ELÉTRICAS  UTILIZANDO ...
# Novo item detectado:  Computação) - Universidade Federal de Goiás. Qual...
# Novo item detectado:  Sthefanie  Monica  Premebida.  Transformer vs.  C...
# Linha ignorada (muito curta): '1.'
# Linha ignorada (muito curta): '1.'
# Linha ignorada (muito curta): '1.'
# Linha ignorada (muito curta): '2.'
# Linha ignorada (muito curta): '3.'
# Linha ignorada (muito curta): '4.'
# Linha ignorada (muito curta): '5.'
# Novo item detectado:  Paraná. Monografias de cursos de aperfeiçoamento/...
# Novo item detectado:  de Treino Dinâmico e Pessoal. 2025 - Universidade...
# Novo item detectado:  Guilherme  Correia  Dutra.CLUSTERIZAÇÃO  DE  DADO...
# Novo item detectado:  Participação em eventos, congressos, exposições e...
# Novo item detectado:  (Congresso). Campus  Party.Automatizando  Process...
# Novo item detectado:  Privacidade e Evitar Viés nos Modelos. 2024. (Enc...
# Linha ignorada (muito curta): '6.'
# Linha ignorada (muito curta): '7.'
# Linha ignorada (muito curta): '8.'
# Linha ignorada (muito curta): '9.'
# Linha ignorada (muito curta): '10.'
# Linha ignorada (muito curta): '11.'
# Linha ignorada (muito curta): '12.'
# Novo item detectado:  approach tomography  employing computed hyperpara...
# Novo item detectado:  TOMOGRAFIA  COMPUTADORIZADA  DE  CRÂNIO.  2023. (...
# Novo item detectado:  pesquisa e inovação no mundo sem fronteira. 2021....
# Novo item detectado:  (Outra). Programa de Formação em Inovação. 2017. ...
# Novo item detectado:  (Congresso). Consegi. Computação em Nuvem. 2010. ...
# Linha ignorada (muito curta): '1.'
# Linha ignorada (muito curta): '1.'
# Novo item detectado:  Orientações Orientações e supervisões concluídas ...
# Novo item detectado:  APLICAÇÃO  DE  UMA  REDE  TIPO  UNET  PARA  ESTUD...
# Novo item detectado:  Tecnológica  Federal  do  Paraná.  Orientador:  P...
# Novo item detectado:  utilizando  diferentes  tipos  de  sistemas  oper...
# Linha ignorada (muito curta): '1.'
# Novo item detectado:  Inovação Patente SANTOS, P. V.. PrimeErp. 2010, B...
# Novo item detectado:  INPI  -  Instituto  Nacional  da  Propriedade  In...
# Novo item detectado:  registro: Patente:  Privilégio  de BR512017000779...
# Novo item detectado:  08/01/2017 Inovação.  Número  do Programa de comp...
# Linha ignorada (muito curta): '2.'
# Linha ignorada (muito curta): '1.'
# Linha ignorada (muito curta): '2.'
# Novo item detectado:  intelligence-based DOS  SANTOS,  PAULO  V..  Arti...
# Linha ignorada (muito curta): '1.'
# Linha ignorada (muito curta): '1.'
# Novo item detectado:  Apresentações de Trabalho SANTOS,  P.  V..  Pales...
# Novo item detectado:  Programa de Computador sem registro de patente SA...
# Novo item detectado:  Outras informações relevantes Curso técnico em ad...
# Novo item detectado:  Somente os dados identificados como públicos pelo...
# Total de itens após chunking: 206
# --- Lendo Certificados ---
# Procurando arquivos PDF na pasta: D:/PycharmProjects/PreparadorLattes/certificados/
# Total de arquivos encontrados: 36
# Lendo (1/36): 55. PAULO VICTOR DOS SANTOS.pdf
# Lendo o arquivo PDF: D:/PycharmProjects/PreparadorLattes/certificados\55. PAULO VICTOR DOS SANTOS.pdf
# Texto extraído com sucesso do arquivo: D:/PycharmProjects/PreparadorLattes/certificados\5...
# Lendo (2/36): 6040ed4df5fa4582a116736ce77c2030.pdf
# Lendo o arquivo PDF: D:/PycharmProjects/PreparadorLattes/certificados\6040ed4df5fa4582a116736ce77c2030.pdf
# Texto extraído com sucesso do arquivo: D:/PycharmProjects/PreparadorLattes/certificados\6...
# Lendo (3/36): ATA DE DEFESA DE DISSERTAÇÃO DE MESTRADO N 22 -natalia.pdf
# Lendo o arquivo PDF: D:/PycharmProjects/PreparadorLattes/certificados\ATA DE DEFESA DE DISSERTAÇÃO DE MESTRADO N 22 -natalia.pdf
# Texto extraído com sucesso do arquivo: D:/PycharmProjects/PreparadorLattes/certificados\A...
# Lendo (4/36): ATA DE DEFESA DE DISSERTAÇÃO DE MESTRADO N 35 -Claudio.pdf
# Lendo o arquivo PDF: D:/PycharmProjects/PreparadorLattes/certificados\ATA DE DEFESA DE DISSERTAÇÃO DE MESTRADO N 35 -Claudio.pdf
# Texto extraído com sucesso do arquivo: D:/PycharmProjects/PreparadorLattes/certificados\A...
# Lendo (5/36): Certificado - 150111109940236.pdf
# Lendo o arquivo PDF: D:/PycharmProjects/PreparadorLattes/certificados\Certificado - 150111109940236.pdf
# Texto extraído com sucesso do arquivo: D:/PycharmProjects/PreparadorLattes/certificados\C...
# Lendo (6/36): Certificado Paulo Victor dos Santos.pdf
# Lendo o arquivo PDF: D:/PycharmProjects/PreparadorLattes/certificados\Certificado Paulo Victor dos Santos.pdf
# Texto extraído com sucesso do arquivo: D:/PycharmProjects/PreparadorLattes/certificados\C...
# Lendo (7/36): CERTIFICADOS_GCITE_PAULO_1.pdf
# Lendo o arquivo PDF: D:/PycharmProjects/PreparadorLattes/certificados\CERTIFICADOS_GCITE_PAULO_1.pdf
# Texto extraído com sucesso do arquivo: D:/PycharmProjects/PreparadorLattes/certificados\C...
# Lendo (8/36): CERTIFICADO_48c9e6ac-70c2-4ad7-9cbf-b5e3eeaa920b (3).pdf
# Lendo o arquivo PDF: D:/PycharmProjects/PreparadorLattes/certificados\CERTIFICADO_48c9e6ac-70c2-4ad7-9cbf-b5e3eeaa920b (3).pdf
# Texto extraído com sucesso do arquivo: D:/PycharmProjects/PreparadorLattes/certificados\C...
# Lendo (9/36): certificado_5120180003241521584144550.pdf
# Lendo o arquivo PDF: D:/PycharmProjects/PreparadorLattes/certificados\certificado_5120180003241521584144550.pdf
# Texto extraído com sucesso do arquivo: D:/PycharmProjects/PreparadorLattes/certificados\c...
# Lendo (10/36): certificado_Paulo Victor dos Santos.pdf
# Lendo o arquivo PDF: D:/PycharmProjects/PreparadorLattes/certificados\certificado_Paulo Victor dos Santos.pdf
# Texto extraído com sucesso do arquivo: D:/PycharmProjects/PreparadorLattes/certificados\c...
# Lendo (11/36): certificado_registro_QualitasV2 (2).pdf
# Lendo o arquivo PDF: D:/PycharmProjects/PreparadorLattes/certificados\certificado_registro_QualitasV2 (2).pdf
# Texto extraído com sucesso do arquivo: D:/PycharmProjects/PreparadorLattes/certificados\c...
# Lendo (12/36): certificado_tecnoshow.pdf
# Lendo o arquivo PDF: D:/PycharmProjects/PreparadorLattes/certificados\certificado_tecnoshow.pdf
# Texto extraído com sucesso do arquivo: D:/PycharmProjects/PreparadorLattes/certificados\c...
# Lendo (13/36): Certificado_Trabalho_5898_PD.pdf
# Lendo o arquivo PDF: D:/PycharmProjects/PreparadorLattes/certificados\Certificado_Trabalho_5898_PD.pdf
# Cannot set gray non-stroke color because /'P1' is an invalid float value
# Texto extraído com sucesso do arquivo: D:/PycharmProjects/PreparadorLattes/certificados\C...
# Lendo (14/36): Coursera U8G96N4ZLHLK.pdf
# Lendo o arquivo PDF: D:/PycharmProjects/PreparadorLattes/certificados\Coursera U8G96N4ZLHLK.pdf
# Texto extraído com sucesso do arquivo: D:/PycharmProjects/PreparadorLattes/certificados\C...
# Lendo (15/36): db2d0d559ffc4e758b7b2d07d9d3fc71.pdf
# Lendo o arquivo PDF: D:/PycharmProjects/PreparadorLattes/certificados\db2d0d559ffc4e758b7b2d07d9d3fc71.pdf
# Texto extraído com sucesso do arquivo: D:/PycharmProjects/PreparadorLattes/certificados\d...
# Lendo (16/36): Declaração - Paulo Victor dos Santos - Aplicações Éticas de IA - Assinado.pdf
# Lendo o arquivo PDF: D:/PycharmProjects/PreparadorLattes/certificados\Declaração - Paulo Victor dos Santos - Aplicações Éticas de IA - Assinado.pdf
# Texto extraído com sucesso do arquivo: D:/PycharmProjects/PreparadorLattes/certificados\D...
# Lendo (17/36): Declaração - Paulo Victor dos Santos - Automatizando Processos com IA - Assinado.pdf
# Lendo o arquivo PDF: D:/PycharmProjects/PreparadorLattes/certificados\Declaração - Paulo Victor dos Santos - Automatizando Processos com IA - Assinado.pdf
# Texto extraído com sucesso do arquivo: D:/PycharmProjects/PreparadorLattes/certificados\D...
# Lendo (18/36): Declaração - Paulo Victor dos Santos - Prática de IA para Advocacia - Assinado.pdf
# Lendo o arquivo PDF: D:/PycharmProjects/PreparadorLattes/certificados\Declaração - Paulo Victor dos Santos - Prática de IA para Advocacia - Assinado.pdf
# Texto extraído com sucesso do arquivo: D:/PycharmProjects/PreparadorLattes/certificados\D...
# Lendo (19/36): DECLARAÇÃO DE PARTICIPAÇÃO À DISTÂNCIA EM BANCA DE DEFESA DE MESTRADO _ UTFPR CÂMPUS PONTA GROSSA -.pdf
# Lendo o arquivo PDF: D:/PycharmProjects/PreparadorLattes/certificados\DECLARAÇÃO DE PARTICIPAÇÃO À DISTÂNCIA EM BANCA DE DEFESA DE MESTRADO _ UTFPR CÂMPUS PONTA GROSSA -.pdf
# Texto extraído com sucesso do arquivo: D:/PycharmProjects/PreparadorLattes/certificados\D...
# Lendo (20/36): DECLARAÇÃO DE PARTICIPAÇÃO À DISTÂNCIA EM BANCA DE QUALIFICAÇÃO DE MESTRADO _ UTFPR CÂMPUS PONTA GROSSA -.pdf
# Lendo o arquivo PDF: D:/PycharmProjects/PreparadorLattes/certificados\DECLARAÇÃO DE PARTICIPAÇÃO À DISTÂNCIA EM BANCA DE QUALIFICAÇÃO DE MESTRADO _ UTFPR CÂMPUS PONTA GROSSA -.pdf
# Texto extraído com sucesso do arquivo: D:/PycharmProjects/PreparadorLattes/certificados\D...
# Lendo (21/36): forum TB - 2022.pdf
# Lendo o arquivo PDF: D:/PycharmProjects/PreparadorLattes/certificados\forum TB - 2022.pdf
# Texto extraído com sucesso do arquivo: D:/PycharmProjects/PreparadorLattes/certificados\f...
# Lendo (22/36): isf-certificado.pdf
# Lendo o arquivo PDF: D:/PycharmProjects/PreparadorLattes/certificados\isf-certificado.pdf
# Texto extraído com sucesso do arquivo: D:/PycharmProjects/PreparadorLattes/certificados\i...
# Lendo (23/36): jp2025.pdf
# Lendo o arquivo PDF: D:/PycharmProjects/PreparadorLattes/certificados\jp2025.pdf
# Texto extraído com sucesso do arquivo: D:/PycharmProjects/PreparadorLattes/certificados\j...
# Lendo (24/36): LA-CCI 2021 Certificate.pdf
# Lendo o arquivo PDF: D:/PycharmProjects/PreparadorLattes/certificados\LA-CCI 2021 Certificate.pdf
# Texto extraído com sucesso do arquivo: D:/PycharmProjects/PreparadorLattes/certificados\L...
# Lendo (25/36): Melhor apresentação .pdf
# Lendo o arquivo PDF: D:/PycharmProjects/PreparadorLattes/certificados\Melhor apresentação .pdf
# Texto extraído com sucesso do arquivo: D:/PycharmProjects/PreparadorLattes/certificados\M...
# Lendo (26/36): PARECER DA DEFESA DE MESTRADO _ UTFPR CÂMPUS CORNÉLIO PROCÓPIO -.pdf
# Lendo o arquivo PDF: D:/PycharmProjects/PreparadorLattes/certificados\PARECER DA DEFESA DE MESTRADO _ UTFPR CÂMPUS CORNÉLIO PROCÓPIO -.pdf
# Texto extraído com sucesso do arquivo: D:/PycharmProjects/PreparadorLattes/certificados\P...
# Lendo (27/36): PARECER DA DEFESA DE MESTRADO _ UTFPR CÂMPUS PONTA GROSSA -.pdf
# Lendo o arquivo PDF: D:/PycharmProjects/PreparadorLattes/certificados\PARECER DA DEFESA DE MESTRADO _ UTFPR CÂMPUS PONTA GROSSA -.pdf
# Texto extraído com sucesso do arquivo: D:/PycharmProjects/PreparadorLattes/certificados\P...
# Lendo (28/36): PARECER DA QUALIFICAÇÃO DE MESTRADO _ UTFPR CÂMPUS PONTA GROSSA -.pdf
# Lendo o arquivo PDF: D:/PycharmProjects/PreparadorLattes/certificados\PARECER DA QUALIFICAÇÃO DE MESTRADO _ UTFPR CÂMPUS PONTA GROSSA -.pdf
# Texto extraído com sucesso do arquivo: D:/PycharmProjects/PreparadorLattes/certificados\P...
# Lendo (29/36): patente primeerp.pdf
# Lendo o arquivo PDF: D:/PycharmProjects/PreparadorLattes/certificados\patente primeerp.pdf
# Texto extraído com sucesso do arquivo: D:/PycharmProjects/PreparadorLattes/certificados\p...
# Lendo (30/36): Paulo Victor dos Santos  - Ouvinte.pdf
# Lendo o arquivo PDF: D:/PycharmProjects/PreparadorLattes/certificados\Paulo Victor dos Santos  - Ouvinte.pdf
# Texto extraído com sucesso do arquivo: D:/PycharmProjects/PreparadorLattes/certificados\P...
# Lendo (31/36): Paulo Victor Dos Santos (1).pdf
# Lendo o arquivo PDF: D:/PycharmProjects/PreparadorLattes/certificados\Paulo Victor Dos Santos (1).pdf
# Texto extraído com sucesso do arquivo: D:/PycharmProjects/PreparadorLattes/certificados\P...
# Lendo (32/36): Paulo Victor dos Santos e PrimeErp - Sistema de gerenciamento de obras e manutenções em redes elétrica.pdf
# Lendo o arquivo PDF: D:/PycharmProjects/PreparadorLattes/certificados\Paulo Victor dos Santos e PrimeErp - Sistema de gerenciamento de obras e manutenções em redes elétrica.pdf
# Texto extraído com sucesso do arquivo: D:/PycharmProjects/PreparadorLattes/certificados\P...
# Lendo (33/36): SEI_UFG - 5459920 - Ata de Exame de Qualificação.pdf
# Lendo o arquivo PDF: D:/PycharmProjects/PreparadorLattes/certificados\SEI_UFG - 5459920 - Ata de Exame de Qualificação.pdf
# Texto extraído com sucesso do arquivo: D:/PycharmProjects/PreparadorLattes/certificados\S...
# Lendo (34/36): UC-0d55ab40-1368-4024-b3fb-d9420ca70ac7.pdf
# Lendo o arquivo PDF: D:/PycharmProjects/PreparadorLattes/certificados\UC-0d55ab40-1368-4024-b3fb-d9420ca70ac7.pdf
# Arquivo aparentemente vazio: D:/PycharmProjects/PreparadorLattes/certificados\UC-0d55ab40-1368-4024-b3fb-d9420ca70ac7.pdf
# Aviso: O arquivo 'UC-0d55ab40-1368-4024-b3fb-d9420ca70ac7.pdf' parece vazio ou pode ser um PDF escaneado.
# Lendo (35/36): workshoe IA na saude - 2023.pdf
# Lendo o arquivo PDF: D:/PycharmProjects/PreparadorLattes/certificados\workshoe IA na saude - 2023.pdf
# Texto extraído com sucesso do arquivo: D:/PycharmProjects/PreparadorLattes/certificados\w...
# Lendo (36/36): [CERTIFICADO] II Seminário do Programa de Pós-Graduação em Engenharia Elétrica e de Computação (PPGEEC) da UFG.pdf
# Lendo o arquivo PDF: D:/PycharmProjects/PreparadorLattes/certificados\[CERTIFICADO] II Seminário do Programa de Pós-Graduação em Engenharia Elétrica e de Computação (PPGEEC) da UFG.pdf
# Texto extraído com sucesso do arquivo: D:/PycharmProjects/PreparadorLattes/certificados\[...
# Aviso: O arquivo '[CERTIFICADO] II Seminário do Programa de Pós-Graduação em Engenharia Elétrica e de Computação (PPGEEC) da UFG.pdf' parece vazio ou pode ser um PDF escaneado.
# Total de certificados processados: 36
# Gerando embeddings para os certificados...
# Iniciando verificação de 206 itens do Lattes...
#
# === RESUMO DA ANÁLISE ===
# Status
# NÃO CONFORME (Certificado não encontrado ou incompatível)    200
# CONFORME                                                       6
# Name: count, dtype: int64
#
# Certificados Sobrando (Órfãos): 30
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[5], line 82
#      79     print(f"Relatório gerado com sucesso: {filename}")
#      81 # Gerar
# ---> 82 generate_pdf_report(df_results, orphan_certs)
#
# Cell In[5], line 78, in generate_pdf_report(dataframe, orphans, filename)
#      75     c.drawString(40, y, f"- {orphan}")
#      76     y -= 15
# ---> 78 c.save()
#      79 print(f"Relatório gerado com sucesso: {filename}")
#
# File D:\PycharmProjects\PreparadorLattes\.venv\lib\site-packages\reportlab\pdfgen\canvas.py:1301, in Canvas.save(self)
#    1297 """Saves and close the PDF document in the file.
#    1298    If there is current data a ShowPage is executed automatically.
#    1299    After this operation the canvas must not be used further."""
#    1300 if len(self._code): self.showPage()
# -> 1301 self._doc.SaveToFile(self._filename, self)
#
# File D:\PycharmProjects\PreparadorLattes\.venv\lib\site-packages\reportlab\pdfbase\pdfdoc.py:208, in PDFDocument.SaveToFile(self, filename, canvas)
#     206     myfile = 1
#     207     filename = makeFileName(filename)
# --> 208     f = open(filename, "wb")
#     209 else:
#     210     raise TypeError('Cannot use %s as a filename or file' % repr(filename))
#
# PermissionError: [Errno 13] Permission denied: 'Relatorio_Conformidade.pdf'

# %% [raw]
# Explicação do Fluxo (Diagrama Mental)
# Ingestão: O código usa pdfminer para transformar PDFs em texto.
#
# Chunking: O Lattes é quebrado em pequenos pedaços de texto (assumindo que cada parágrafo/bloco é um item a ser provado).
#
# Vetorização (Embeddings): Usamos a OpenAI para transformar o conteúdo de cada certificado em números.
#
# Indexação (FAISS): Esses números são colocados em um índice pesquisável de alta velocidade.
#
# Busca Semântica: Para cada item do Lattes, perguntamos ao FAISS: "Qual certificado tem o conteúdo mais parecido com este texto?".
#
# O Juiz (LLM): O FAISS pode achar algo parecido, mas não exato. O GPT-4 recebe os dois textos e julga a veracidade, retornando um JSON estruturado.
#
# Relatório: O reportlab desenha o PDF final com os itens não conformes (vermelho) e os certificados sobrando (órfãos).
#
# Próximos Passos Sugeridos
# Gostaria que eu adaptasse o código para lidar com certificados escaneados (imagens)? Nesse caso, precisaríamos adicionar uma etapa de OCR (Reconhecimento Óptico de Caracteres) usando pytesseract ou Azure, pois o pdfminer não lê imagens.
